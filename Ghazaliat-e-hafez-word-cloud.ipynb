# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver

# %%
def write_to_txt(text_list, filename):
    """Writes a list of strings to a text file.

    Args:
        text_list: A list of strings to be written to the file.
        filename: The name of the output text file.
    """
    file_path = fr"C:\Users\4R4S8\Desktop\PYTHON\Jenab-e-Hafez\ghazal-ha-text\{filename}"
    try:
        with open(file_path, 'w', encoding='utf-8') as file:
            for line in text_list:
                file.write(line + '\n')
        print(f"Text written to {file_path} successfully.")
    except IOError:
        print(f"Error writing to file: {file_path}")

# %%
def generate_new_soup(ghagzal_number):  
    url=f'https://ganjoor.net/hafez/ghazal/sh{ghagzal_number}'
    print(url)
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        print("Fresh soup is ready!")
        return soup
    else:
        print(f"Error fetching URL: {response.status_code}")

# %%
def get_ghazal_name(soup):
    # Find the h2 element
    h2_element = soup.find('article')

    # Find the anchor tag within the h2 element
    a_element = h2_element.findAll('a')

    # Extract the text from the anchor tag
    # extracted_text = a_element

    # print(h2_element)
    ghazal_name=a_element[3].text.strip()
    print(ghazal_name)
    
    return ghazal_name

# %%
def get_ghazal_text(soup):
    divs = soup.find('article')
    abyat_text = []
    for abyat in divs.findAll('p'):
        abyat_text.append(abyat.text)
    print(abyat_text)
    return abyat_text

# %%
for ghazal in range(1,496):
    soup = generate_new_soup(str(ghazal))
    ghazal_name= get_ghazal_name(soup)
    abyat_text = get_ghazal_text(soup)
    write_to_txt(abyat_text,ghazal_name+'.txt')
# Out:
# https://ganjoor.net/hafez/ghazal/sh1
# Fresh soup is ready!
# غزل شمارهٔ ۱
# ['اَلا یا اَیُّهَا السّاقی اَدِرْ کَأسَاً و ناوِلْها', 'که عشق آسان نمود اوّل ولی افتاد مشکل\u200cها', 'به بویِ نافه\u200cای کآخر صبا زان طُرّه بُگشاید', 'ز تابِ جَعدِ مُشکینش چه خون افتاد در دل\u200cها', 'مرا در منزلِ جانان چه اَمنِ عیش، چون هر دَم', 'جَرَس فریاد می\u200cدارد که بَربندید مَحمِل\u200cها', 'به مِی سجّاده رنگین کُن گَرَت پیرِ مُغان گوید', 'که سالِک بی\u200cخبر نَبْوَد ز راه و رسمِ منزل\u200cها', 'شبِ تاریک و بیمِ موج و گِردابی چنین هایل', 'کجا دانند حالِ ما سبکبارانِ ساحل\u200cها؟', 'همه کارم ز خودکامی به بدنامی کشید آخر', 'نهان کِی مانَد آن رازی کَزو سازند مَحفِل\u200cها؟', 'حضوری گر همی\u200cخواهی از او غایب مشو حافظ', 'مَتٰی ما تَلْقَ مَنْ تَهْویٰ دَعِ الدُّنْیا و اَهْمِلْها']
# Text written to C:\Users\4R4S8\Desktop\PYTHON\Jenab-e-Hafez\ghazal-ha-text\غزل شمارهٔ ۱.txt successfully.
# https://ganjoor.net/hafez/ghazal/sh2
# Fresh soup is ready!
# غزل شمارهٔ ۲
# ...
